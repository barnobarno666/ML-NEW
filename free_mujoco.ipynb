# %% [markdown]
# <a href="https://colab.research.google.com/github/barnobarno666/ML-NEW/blob/master/free_mujoco.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get install -y \
    libgl1-mesa-dev \
    libgl1-mesa-glx \
    libglew-dev \
    libosmesa6-dev \
    software-properties-common

# !apt-get install -y patchelf

# %%
# !pip install gym

# %%
# !pip install free-mujoco-py

# %% [markdown]
# **Now you need to restart the runtime as numpy is apparently automatically imported...**

# %%
import mujoco_py
import gym

# %%
env = gym.make("HalfCheetah-v2")

print(env.reset().shape)

# %%
# !pip install stable-baselines3 sb3-contrib

# %%
from sb3_contrib import TQC

model = TQC("MlpPolicy", "HalfCheetah-v2", verbose=1).learn(500_000)
# Out:
# Using cpu device
# Creating environment from the given name 'HalfCheetah-v2'
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -262     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 23       |
# |    time_elapsed    | 166      |
# |    total_timesteps | 4000     |
# | train/             |          |
# |    actor_loss      | -32      |
# |    critic_loss     | 0.327    |
# |    ent_coef        | 0.313    |
# |    ent_coef_loss   | -11.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -218     |
# | time/              |          |
# |    episodes        | 8        |
# ...
